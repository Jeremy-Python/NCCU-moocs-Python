# %% [markdown]
# ## 挑戰題一：寫個函數讓字串倒過來排
#
# 題目說明：寫一個函數，比如說叫 reverse，然後輸入一個字串，如下：
#
# st = “hello”
#
# reverse(“hello”)
#
# 就回傳這個字串：‘olleh’

# %%
#挑戰題1
def reverse(x):
  i=len(x)
  for i in range (i-1,-1,-1):
    print(x[i],end="")
  return 

a=input()
reverse(a)
# Out:
# hello
# olleh

# %%
#挑戰題1 另一種解法
a=input()
print(a[::-1])
# Out:
# hello
# olleh
